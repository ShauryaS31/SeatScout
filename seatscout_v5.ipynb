# %% [markdown]
# # SeatScoutv5

# %%
from ultralytics import YOLO

model = YOLO('yolo12m.pt')

# %%
model.train(
    data='data.yaml',
    epochs=500,
    imgsz=1024,
    batch=7,
    workers=8,
    optimizer='SGD',
    lr0=0.0005,
    weight_decay=0.0005,
    patience=25,
    seed=42,
    project='seatscoutv5',
    name='training',
    save=True,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.144 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.143 🚀 Python-3.10.16 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# ...

# %% [markdown]
# ### Loading the best weights

# %%
from ultralytics import YOLO
model = YOLO('seatscoutv5/training/weights/best.pt')

# %% [markdown]
# ## Evaluating the performance of the model

# %%
data_path = 'data.yaml'

# %% [markdown]
# ### Creating a function to pretty print metrics per class

# %%
def print_class_metrics(results):

    CLASSES = ['chair', 'human']

    # Print the header for per-class AP/AR table
    print("\nAP / AR per class\n" + "-"*73)
    print(f"| {'ID':<3} | {'Class':<20} | {'AP':<18} | {'AR':<18} |")
    print("-"*73)

    # Loop through each class
    for i, cls in enumerate(CLASSES):
        # Get AP and AR for the current class
        ap = results.box.maps[i]
        ar = results.box.r[i]
    
        # Print formatted row
        print(f"| {i:<3} | {cls:<20} | {ap:<18.3f} | {ar:<18.3f} |")

    # Print average AP and AR across all classes
    print("-"*73)
    print(f"| {'Avg':<24} | {results.box.map:<18.3f} | {results.box.mr:<18.3f} |")
    print("-"*73)

# %% [markdown]
# ### Training set performance

# %%
train_results = model.val(data=data_path, split='train')
print_class_metrics(train_results)
# Out:
# Ultralytics 8.3.143 🚀 Python-3.10.16 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.9±0.1 ms, read: 334.0±51.4 MB/s, size: 1525.5 KB)
# val: Scanning /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/labels/train.cache... 292 images, 0 backgrounds, 0 corrupt: 100%|██████████| 292/292 [00:00<?, ?it/s]
# train: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/train/139.png: 1 duplicate labels removed
# train: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/train/141.png: 1 duplicate labels removed
# train: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/train/143.png: 1 duplicate labels removed
# train: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/train/146.png: 1 duplicate labels removed
# train: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/train/147.png: 1 duplicate labels removed
# ...

# %% [markdown]
# ### Validation set performance

# %%
val_results = model.val(data=data_path, split='val')
print_class_metrics(val_results)
# Out:
# Ultralytics 8.3.143 🚀 Python-3.10.16 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# val: Fast image access ✅ (ping: 0.9±0.1 ms, read: 322.8±89.1 MB/s, size: 1467.7 KB)
# val: Scanning /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/labels/val.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/144.png: 1 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/325.png: 3 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/328.png: 3 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/332.png: 3 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/344.png: 3 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/val/346.png: 3 duplicate labels removed
# ...

# %% [markdown]
# ### Test set performance

# %%
test_results = model.val(data=data_path, split='test')
print_class_metrics(test_results)
# Out:
# Ultralytics 8.3.143 🚀 Python-3.10.16 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# YOLOv12m summary (fused): 169 layers, 20,106,454 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.8±0.2 ms, read: 145.8±51.3 MB/s, size: 1093.3 KB)
# val: Scanning /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/labels/test.cache... 64 images, 0 backgrounds, 0 corrupt: 100%|██████████| 64/64 [00:00<?, ?it/s]
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/test/142.png: 1 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/test/145.png: 1 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/test/155.png: 1 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/test/330.png: 3 duplicate labels removed
# val: /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v5/images/test/345.png: 3 duplicate labels removed
# ...

# %% [markdown]
# ### Inference example

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2

img_path = 'data/dataset_v2/images/test/59.png' #'sample_image.png'

def inference(img_path):
# Predict
    results = model.predict(source=img_path, conf=0.6)
    result = results[0]

    # Pull clean data
    img_bgr = result.orig_img
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    boxes = result.boxes.xyxy.cpu()
    scores = result.boxes.conf.cpu()
    labels = result.boxes.cls.cpu().int()

    class_colors = {
        "human": "red",
        "chair": "green",
        "table": "#33C1FF",
    }

    plt.figure(figsize=(12, 8))
    plt.imshow(img_rgb)
    ax = plt.gca()

    for (x1, y1, x2, y2), score, label in zip(boxes, scores, labels):
        if score > 0.6:
            class_name = model.names[label.item()]
            color = class_colors.get(class_name, 'yellow')  # default color
            ax.add_patch(plt.Rectangle((x1, y1), x2-x1, y2-y1,
                                    edgecolor=color, facecolor='none', linewidth=2))
            ax.text(x1, y1-5, f'{class_name}: {score:.2f}',
                    color='white', fontsize=10,
                    bbox=dict(facecolor=color, alpha=0.5, edgecolor='none'))

    plt.axis('off')
    plt.title(f'Predictions for {img_path.split("/")[-1]}')
    plt.show()

inference(img_path)
# Out:
# image 1/1 /mnt/c/Users/mohda/.vscode/seatscout/data/dataset_v2/images/test/59.png: 1024x1024 3 humans, 6 chairs, 26.8ms
# Speed: 1.8ms preprocess, 26.8ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 1024)

# %% [markdown]
# ### Normalized Confusion Matrix

# %%
from PIL import Image
import matplotlib.pyplot as plt
img_path ="runs/detect/val10/confusion_matrix_normalized.png"
img = Image.open(img_path)
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Inference Samples

# %%
from PIL import Image
import matplotlib.pyplot as plt
img_path ="runs/detect/val10/val_batch1_labels.jpg"
img = Image.open(img_path)
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
